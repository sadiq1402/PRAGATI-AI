# %% [markdown]
# ## F1-Score

# %% [markdown]
# ![BoxF1_curve.png](attachment:2afe9bef-5cf3-446f-870f-7adc86289bb3.png)

# %% [markdown]
# ## Precision-Confidence Curve

# %% [markdown]
# ![BoxP_curve.png](attachment:251eb43d-546e-430c-835e-1c9db37d44bb.png)

# %% [markdown]
# ## Box-Precision Curve

# %% [markdown]
# ![BoxP_curve.png](attachment:8ce6f6d9-904c-4ce1-9494-1ce64e4ff49d.png)

# %% [markdown]
# ## Recall-Confidence Curve

# %% [markdown]
# ![BoxR_curve.png](attachment:aec5f856-78a1-465e-8319-5554659a04e3.png)

# %% [markdown]
# ## Confusion-Matrix-Normalized

# %% [markdown]
# ![confusion_matrix_normalized.png](attachment:1bee4925-c40a-4ffd-9d87-162ef9601d7d.png)
